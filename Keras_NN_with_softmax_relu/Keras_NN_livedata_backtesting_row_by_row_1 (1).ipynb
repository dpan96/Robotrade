# %% [markdown]
# ## Installing the important packages that include, fxcmpy and python-socket these packages are not available on the colab environment. Importing the other important packages as well.

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-1e169df7bc9f> in <module>
# ----> 1 import tensorflow as tf
#       2 physical_devices = tf.config.list_physical_devices('GPU')
#       3 tf.config.experimental.set_memory_growth(physical_devices[0], True)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\__init__.py in <module>
#      48 import numpy as np
#      49
# ---> 50 from tensorflow.python import pywrap_tensorflow
#      51
#      52 # Protocol buffers
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      23 import traceback
#      24
# ---> 25 from tensorflow.python.platform import self_check
#      26
#      27
#
# ModuleNotFoundError: No module named 'tensorflow.python.platform'

# %%
import os
#!wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
#!tar xvzf ta-lib-0.4.0-src.tar.gz
#os.chdir('ta-lib')
#!./configure --prefix=/usr
#!make install

#os.chdir('../')
#!pip install TA-Lib
#!pip install -q scikit-plot

# %%
# Installing the packages. 
# !pip install fxcmpy
# !pip install python-socketio
# !pip install tensorflow
# Out:
# Collecting fxcmpy
#   Using cached fxcmpy-1.2.6-py3-none-any.whl (27 kB)
# Requirement already satisfied: socketIO-client in c:\users\kohli\appdata\roaming\python\python37\site-packages (from fxcmpy) (0.7.2)
# Requirement already satisfied: requests[socks] in c:\users\kohli\anaconda3\lib\site-packages (from fxcmpy) (2.22.0)
# Requirement already satisfied: configparser in c:\users\kohli\appdata\roaming\python\python37\site-packages (from fxcmpy) (5.0.0)
# Requirement already satisfied: pandas in c:\users\kohli\anaconda3\lib\site-packages (from fxcmpy) (1.0.1)
# Requirement already satisfied: websocket-client in c:\users\kohli\appdata\roaming\python\python37\site-packages (from socketIO-client->fxcmpy) (0.57.0)
# Requirement already satisfied: six in c:\users\kohli\anaconda3\lib\site-packages (from socketIO-client->fxcmpy) (1.14.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kohli\anaconda3\lib\site-packages (from requests[socks]->fxcmpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kohli\anaconda3\lib\site-packages (from requests[socks]->fxcmpy) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kohli\anaconda3\lib\site-packages (from requests[socks]->fxcmpy) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kohli\anaconda3\lib\site-packages (from requests[socks]->fxcmpy) (1.25.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\kohli\anaconda3\lib\site-packages (from requests[socks]->fxcmpy) (1.7.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\kohli\anaconda3\lib\site-packages (from pandas->fxcmpy) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\kohli\anaconda3\lib\site-packages (from pandas->fxcmpy) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\kohli\anaconda3\lib\site-packages (from pandas->fxcmpy) (2.8.1)
# Installing collected packages: fxcmpy
# Successfully installed fxcmpy-1.2.6
# Collecting python-socketio
#   Downloading python_socketio-4.6.0-py2.py3-none-any.whl (51 kB)
# Collecting python-engineio>=3.13.0
#   Downloading python_engineio-3.13.0-py2.py3-none-any.whl (49 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\kohli\anaconda3\lib\site-packages (from python-socketio) (1.14.0)
# Installing collected packages: python-engineio, python-socketio
# Successfully installed python-engineio-3.13.0 python-socketio-4.6.0
# Collecting tensorflow
#   Using cached tensorflow-2.2.0-cp37-cp37m-win_amd64.whl (459.2 MB)
# Requirement already satisfied: protobuf>=3.8.0 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorflow) (3.12.2)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Using cached tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\kohli\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Using cached tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in c:\users\kohli\anaconda3\lib\site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\kohli\anaconda3\lib\site-packages (from tensorflow) (1.18.1)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorflow) (1.29.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in c:\users\kohli\anaconda3\lib\site-packages (from tensorflow) (1.4.1)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\kohli\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Collecting keras-preprocessing>=1.1.0
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorflow) (0.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\kohli\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: setuptools in c:\users\kohli\anaconda3\lib\site-packages (from protobuf>=3.8.0->tensorflow) (45.2.0.post20200210)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\kohli\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.6.0.post3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.18.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kohli\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (3.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in c:\users\kohli\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kohli\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kohli\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kohli\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kohli\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2019.11.28)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\kohli\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kohli\appdata\roaming\python\python37\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\kohli\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.2.0)
# Installing collected packages: tensorboard, tensorflow-estimator, gast, keras-preprocessing, tensorflow
# Successfully installed gast-0.3.3 keras-preprocessing-1.1.2 tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0
# ERROR: -ensorflow-gpu 2.1.0 requires astor>=0.6.0, which is not installed.
# ERROR: -ensorflow-gpu 2.1.0 requires keras-applications>=1.0.8, which is not installed.
# ERROR: -ensorflow-gpu 2.1.0 requires tensorflow-gpu-estimator<2.2.0,>=2.1.0rc0, which is not installed.
# ERROR: -ensorflow-gpu 2.1.0 has requirement gast==0.2.2, but you'll have gast 0.3.3 which is incompatible.
# ERROR: -ensorflow-gpu 2.1.0 has requirement tensorboard<2.2.0,>=2.1.0, but you'll have tensorboard 2.2.2 which is incompatible.

# %%
# Important package imports. 
import fxcmpy
import datetime as dt
import time

import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras import layers
from keras.optimizers import SGD
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization

import sklearn
import sqlite3
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-09d231ecee20> in <module>
#       4 import time
#       5
# ----> 6 import tensorflow as tf
#       7 import pandas as pd
#       8 import numpy as np
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\__init__.py in <module>
#      48 import numpy as np
#      49
# ---> 50 from tensorflow.python import pywrap_tensorflow
#      51
#      52 # Protocol buffers
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      23 import traceback
#      24
# ---> 25 from tensorflow.python.platform import self_check
#      26
#      27
#
# ModuleNotFoundError: No module named 'tensorflow.python.platform'

# %% [markdown]
# ## Upload the model to the colab environment. Then run the following code.
#
# This code loads the model.

# %%
''' keras.models.load_model loads the existing trained model
    keras_nn_aud_usd_h4_80%_train_without_fit_transform_2.h5 is used for H4 dataset and is trained on AUDUSD pair
    keras_nn_eur_usd_h1_train_without_fit_transform_2.h5 is used for H1 dataset and is trained on EURUSD pair
'''

classifier = keras.models.load_model('keras_nn_aud_usd_h4_train_with_fit_transform_.h5')

# %% [markdown]
# # Connecting to FXCMPY and getting the data.
#
# Function to store the data into new_data.csv

# %%
## Connecting to fxcm. 
token = "a051ed2f89fe5ae6c3c2a0070af4243cb55d7357"
con = fxcmpy.fxcmpy(access_token=token, log_level='error', server='demo', log_file= None)

# %%
import numpy
import math
import pandas as pd
import numpy as np
import talib
#### keras
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras import layers
from keras.optimizers import SGD
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
#import scikitplot as skplt
import matplotlib.pyplot as plt

# %% [markdown]
# # Running all the backtesting code and printing the results.

# %%
##Making the csv
def make_csv(name, num):
    df = con.get_candles(name, period='H4', number = num)
    df.rename(columns={'bidhigh':'high',
                      'bidlow':'low',
                      'bidopen':'open',
                      'bidclose': 'close'}, 
             inplace=True)
    df['dateime'] = df.index
    df = df[['dateime', 'open', 'close', 'low','high']]
    df.reset_index(drop=True, inplace=True)
    new_name = name[:3] + name[4:]
    return df

# %%
new_data = make_csv('AUD/USD', 1000)
new_data.to_csv('new_data.csv', index=False)

# %%
# This block is used to filter the data from fxcm whic doen't work on weekends
name = 'AUD/USD'
num = 1000
df = con.get_candles(name, period='H4', number = num)
df.rename(columns={'bidhigh':'high',
                  'bidlow':'low',
                  'bidopen':'open',
                  'bidclose': 'close'}, 
          inplace=True)
df['datetime'] = df.index

df = df[['datetime', 'open', 'close', 'low','high']]
df.reset_index(drop=True, inplace=True)
new_name = name[:3] + name[4:]
df.to_csv('trial_new_data.csv',index=False)
df = pd.read_csv('trial_new_data.csv') 
df.reset_index(inplace=True, drop=True)

# %%
#  This block is used to call local dataset to test on weekends
df = pd.read_csv('trial_new_data.csv') 
df.reset_index(inplace=True, drop=True)
df
# Out:
#                 datetime     open    close      low     high
# 0    2019-11-01 13:00:00  0.68923  0.69140  0.68922  0.69211
# 1    2019-11-01 17:00:00  0.69140  0.69122  0.69053  0.69149
# 2    2019-11-03 18:00:00  0.69122  0.69084  0.69108  0.69191
# 3    2019-11-03 22:00:00  0.69126  0.69131  0.69031  0.69174
# 4    2019-11-04 02:00:00  0.69131  0.69193  0.69129  0.69230
# ..                   ...      ...      ...      ...      ...
# 995  2020-06-18 01:00:00  0.68729  0.68772  0.68367  0.68871
# 996  2020-06-18 05:00:00  0.68772  0.68949  0.68570  0.69020
# 997  2020-06-18 09:00:00  0.68949  0.68577  0.68522  0.69001
# 998  2020-06-18 13:00:00  0.68577  0.68418  0.68355  0.68677
# 999  2020-06-18 17:00:00  0.68418  0.68465  0.68375  0.68530
#
# [1000 rows x 5 columns]

# %%
try:
    df = df.drop(['Unnamed: 0'], axis=1)
except:
    pass
try:
    df = df.drop(['volume'], axis=1)
except:
    pass
df
# Out:
#                 datetime     open    close      low     high
# 0    2019-11-01 13:00:00  0.68923  0.69140  0.68922  0.69211
# 1    2019-11-01 17:00:00  0.69140  0.69122  0.69053  0.69149
# 2    2019-11-03 18:00:00  0.69122  0.69084  0.69108  0.69191
# 3    2019-11-03 22:00:00  0.69126  0.69131  0.69031  0.69174
# 4    2019-11-04 02:00:00  0.69131  0.69193  0.69129  0.69230
# ..                   ...      ...      ...      ...      ...
# 995  2020-06-18 01:00:00  0.68729  0.68772  0.68367  0.68871
# 996  2020-06-18 05:00:00  0.68772  0.68949  0.68570  0.69020
# 997  2020-06-18 09:00:00  0.68949  0.68577  0.68522  0.69001
# 998  2020-06-18 13:00:00  0.68577  0.68418  0.68355  0.68677
# 999  2020-06-18 17:00:00  0.68418  0.68465  0.68375  0.68530
#
# [1000 rows x 5 columns]

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.columns = ['datetime','open','close', 'low','high',]

open_prices = df['open']
close_prices = df['close']
high_prices = df['high']
low_prices = df['low']
df_date = df['datetime']

supported = ["ROCP", "MACD", "RSI", "UO", "BOLL", "MA", "STOCH", "AO", "ROC", "WILLR"]

# extraction of features using supported indicators
list_is = ["ROCP1", "ROCP2", "norm_macd", "norm_signal", "norm_hist", "macdrocp", "singalrocp", "histrocp",
            "rsi6", "rsi12", "rsi24", "rsi6rocp", "rsi12rocp", "rsi24rocp", "UO", "upperBOLL", "middleBOLL",
            "lowerBOLL", "MA5rocp", "MA10rocp", "MA20rocp", "MA25rocp", "MA30rocp", "MA40rocp", "MA50rocp", "MA60rocp", 
            "MA5", "MA10", "MA20", "MA25", "MA30", "MA40", "MA50", "MA60", "Slow_stochk", "Slow_stochd", 
            "Fast_stochk", "Fast_stochd", "Fast_stoch_rsik", "Fast_stoch_rsid", "AO","ROC5", "ROC10", "ROC20",
            "ROC25", "WILLR"]

df
# Out:
#                 datetime     open    close      low     high
# 0    2019-11-01 13:00:00  0.68923  0.69140  0.68922  0.69211
# 1    2019-11-01 17:00:00  0.69140  0.69122  0.69053  0.69149
# 2    2019-11-03 18:00:00  0.69122  0.69084  0.69108  0.69191
# 3    2019-11-03 22:00:00  0.69126  0.69131  0.69031  0.69174
# 4    2019-11-04 02:00:00  0.69131  0.69193  0.69129  0.69230
# ..                   ...      ...      ...      ...      ...
# 995  2020-06-18 01:00:00  0.68729  0.68772  0.68367  0.68871
# 996  2020-06-18 05:00:00  0.68772  0.68949  0.68570  0.69020
# 997  2020-06-18 09:00:00  0.68949  0.68577  0.68522  0.69001
# 998  2020-06-18 13:00:00  0.68577  0.68418  0.68355  0.68677
# 999  2020-06-18 17:00:00  0.68418  0.68465  0.68375  0.68530
#
# [1000 rows x 5 columns]

# %%
feature = []
def extract_by_type(feature_type, open_prices=None, close_prices=None, high_prices=None, low_prices=None):

    if feature_type == 'ROCP':
        rocp1 = talib.ROCP(close_prices, timeperiod=1)
        rocp2 = talib.ROCP(close_prices, timeperiod=2)
        feature.append(rocp1)
        feature.append(rocp2)
    if feature_type == 'OROCP':
        orocp = talib.ROCP(open_prices, timeperiod=1)
        feature.append(orocp)
    if feature_type == 'HROCP':
        hrocp = talib.ROCP(high_prices, timeperiod=1)
        feature.append(hrocp)
    if feature_type == 'LROCP':
        lrocp = talib.ROCP(low_prices, timeperiod=1)
        feature.append(lrocp)
    if feature_type == 'MACD':
        macd, signal, hist = talib.MACD(close_prices, fastperiod=12, slowperiod=26, signalperiod=9)
        norm_macd = numpy.nan_to_num(macd) / math.sqrt(numpy.var(numpy.nan_to_num(macd)))
        norm_signal = numpy.nan_to_num(signal) / math.sqrt(numpy.var(numpy.nan_to_num(signal)))
        norm_hist = numpy.nan_to_num(hist) / math.sqrt(numpy.var(numpy.nan_to_num(hist)))
        macdrocp = talib.ROCP(norm_macd + numpy.max(norm_macd) - numpy.min(norm_macd), timeperiod=1)
        signalrocp = talib.ROCP(norm_signal + numpy.max(norm_signal) - numpy.min(norm_signal), timeperiod=1)
        histrocp = talib.ROCP(norm_hist + numpy.max(norm_hist) - numpy.min(norm_hist), timeperiod=1)
        # feature.append(macd / 100.0)
        # feature.append(signal / 100.0)
        # feature.append(hist / 100.0)
        feature.append(norm_macd)
        feature.append(norm_signal)
        feature.append(norm_hist)

        feature.append(macdrocp)
        feature.append(signalrocp)
        feature.append(histrocp)
    if feature_type == 'RSI':
        rsi6 = talib.RSI(close_prices, timeperiod=6)
        rsi12 = talib.RSI(close_prices, timeperiod=12)
        rsi24 = talib.RSI(close_prices, timeperiod=24)
        rsi6rocp = talib.ROCP(rsi6 + 100., timeperiod=1)
        rsi12rocp = talib.ROCP(rsi12 + 100., timeperiod=1)
        rsi24rocp = talib.ROCP(rsi24 + 100., timeperiod=1)
        feature.append(rsi6 / 100.0 - 0.5)
        feature.append(rsi12 / 100.0 - 0.5)
        feature.append(rsi24 / 100.0 - 0.5)
        feature.append(rsi6rocp)
        feature.append(rsi12rocp)
        feature.append(rsi24rocp)
    if feature_type == 'UO':
        ult_osc = talib.ULTOSC(high_prices, low_prices, close_prices, timeperiod1=7, timeperiod2=14, timeperiod3=28)
        feature.append(ult_osc / 100.0 - 0.5)
    if feature_type == 'BOLL':
        upperband, middleband, lowerband = talib.BBANDS(close_prices, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
        feature.append((upperband - close_prices) / close_prices)
        feature.append((middleband - close_prices) / close_prices)
        feature.append((lowerband - close_prices) / close_prices)         
    if feature_type == 'MA':
        ma5 = talib.MA(close_prices, timeperiod=5)
        ma10 = talib.MA(close_prices, timeperiod=10)
        ma20 = talib.MA(close_prices, timeperiod=20)
        ma25 = talib.MA(close_prices, timeperiod=25)
        ma30 = talib.MA(close_prices, timeperiod=30)
        ma40 = talib.MA(close_prices, timeperiod=40)
        ma50 = talib.MA(close_prices, timeperiod=50)
        ma60 = talib.MA(close_prices, timeperiod=60)
        ma5rocp = talib.ROCP(ma5, timeperiod=1)
        ma10rocp = talib.ROCP(ma10, timeperiod=1)
        ma20rocp = talib.ROCP(ma20, timeperiod=1)
        ma25rocp = talib.ROCP(ma25, timeperiod=1)
        ma30rocp = talib.ROCP(ma30, timeperiod=1)
        ma40rocp = talib.ROCP(ma40, timeperiod=1)
        ma50rocp = talib.ROCP(ma50, timeperiod=1)
        ma60rocp = talib.ROCP(ma60, timeperiod=1)
        feature.append(ma5rocp)
        feature.append(ma10rocp)
        feature.append(ma20rocp)
        feature.append(ma25rocp)
        feature.append(ma30rocp)
        feature.append(ma40rocp)
        feature.append(ma50rocp)
        feature.append(ma60rocp)
        feature.append((ma5 - close_prices) / close_prices)
        feature.append((ma10 - close_prices) / close_prices)
        feature.append((ma20 - close_prices) / close_prices)
        feature.append((ma25 - close_prices) / close_prices)
        feature.append((ma30 - close_prices) / close_prices)
        feature.append((ma40 - close_prices) / close_prices)
        feature.append((ma50 - close_prices) / close_prices)
        feature.append((ma60 - close_prices) / close_prices)
    if feature_type == 'STOCH':
        slow_stoch_k, slow_stoch_d = talib.STOCH(high_prices ,low_prices ,close_prices ,fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
        fast_stoch_k, fast_stoch_d = talib.STOCHF(high_prices , low_prices , close_prices , fastk_period=5, fastd_period=3, fastd_matype=0)
        fast_rsi_k, fast_rsi_d = talib.STOCHRSI(close_prices, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)                      
        feature.append(slow_stoch_k / 100.0 - 0.5)
        feature.append(slow_stoch_d / 100.0 - 0.5)
        feature.append(fast_stoch_k / 100.0 - 0.5)
        feature.append(fast_stoch_d / 100.0 - 0.5)
        feature.append(fast_rsi_k / 100.0 - 0.5)
        feature.append(fast_rsi_d / 100.0 - 0.5)
    if feature_type == 'AO':          
        median_price = (high_prices + low_prices) / 2
        ao = talib.SMA(median_price, 5)-talib.SMA(median_price, 34)          
        feature.append(ao)
    if feature_type == 'ROC':
        roc5 = talib.ROC(close_prices, timeperiod=5)
        roc10 = talib.ROC(close_prices, timeperiod=10)
        roc20 = talib.ROC(close_prices, timeperiod=20)
        roc25 = talib.ROC(close_prices, timeperiod=25)
        feature.append(roc5)
        feature.append(roc10)
        feature.append(roc20)
        feature.append(roc25)
    if feature_type == 'WILLR':
        willr = talib.WILLR(high_prices,low_prices,close_prices, timeperiod=14)
        feature.append(willr / 100.0 - 0.5)

    return feature

# %%
from collections import deque

buysq = deque([])
sellsq = deque([])

buy = 0
sell= 0

#dataframe to store trading records
col_names =  ['size', 'open_rate', 'open_date','sl','tp','close_rate','close_date','P/L']
sy1 = pd.DataFrame(columns = col_names)
sy2 = pd.DataFrame(columns = col_names)
#setting stop loss and take profit, e.g. 100 pips in this case
sl = 0.0020
tp = 0.0030

signal = ""
count = 0
count_1 = 0

# %%
sy1
# Out:
# Empty DataFrame
# Columns: [size, open_rate, open_date, sl, tp, close_rate, close_date, P/L]
# Index: []

# %%
# sys1 only closes trades when stop loss of take profit reached
def sys1(sy1, action, price, datetime, sl, tp):
    sy1 = sy1.append({'size': action, 'open_rate': price, 'open_date': datetime, 'sl': price - sl,'tp': price + tp},ignore_index=True)
    return sy1

def check_price(df, price, high, low, datetime, signal):
    #close trades when reach the stoploss or take profit level
    for index, row in df.iterrows():
        if np.isnan(row['close_rate']) and ~np.isnan(row['open_rate']):
            if (price - df['open_rate'][index]) < tp and (price - df['open_rate'][index]) > sl:
                if signal == 'Buy' or signal == 'Sell':
                    df['close_rate'][index] = price
                    df['close_date'][index] = datetime
                    df['P/L'][index] =  df['close_rate'][index] - df['open_rate'][index]
                    print("profit/loss")
            elif high >= row['tp'] and signal == 'Buy':
                df['close_rate'][index] = price
                df['close_date'][index] = datetime
                df['P/L'][index] = df['close_rate'][index] - df['open_rate'][index]
                print("T/P")
            elif low <= row['sl'] and signal == 'Buy':
                df['close_rate'][index] = price
                df['close_date'][index] = datetime
                df['P/L'][index] = df['close_rate'][index] - df['open_rate'][index]
                print("S/L")
            elif low <= row['tp'] and signal == 'Sell':
                df['close_rate'][index] = price
                df['close_date'][index] = datetime
                df['P/L'][index] = df['close_rate'][index] - df['open_rate'][index]
                print("T/P")
            elif high >= row['tp'] and signal == 'Sell':
                df['close_rate'][index] = price
                df['close_date'][index] = datetime
                df['P/L'][index] = df['close_rate'][index] - df['open_rate'][index]       
                print("S/L")

    return df

# %%
open_list = []
close_list = []
high_list = []
low_list = []
feature = []
# if predictions[df.index[-1]] == 2:
#             if row['high'][i] >= buy[2] + tp:
#                 buy_trades_pnl.append((2,row['close'],'buy ',buy[2],row['date'][i],row['high'][i],tp,'t/p hit',i))
#                 break
#             elif row['low'][i] <= buy[2] - sl:
#                 buy_trades_pnl.append((buy[0],buy[1],'buy ',buy[2],row['date'][i],row['low'][i],-sl,'s/l hit', i))
#                 break
#             elif predictions[i] == 0:
#                 buy_trades_pnl.append((buy[0],buy[1],'buy ',buy[2],row['date'][i],row['close'][i],
#                                   (row['close'][i]-buy[2]),'prediction change', i))
#                 break

#         if predictions[df.index[-1]] == 0:
#             if row['low'][i] <= sell[2] - tp:
#                 sell_trades_pnl.append((sell[0],sell[1],'sell',sell[2],row['date'][i],row['low'][i],tp,'t/p hit',i))
#                 break
#             elif df['high'][i] >= sell[2] + sl:
#                 sell_trades_pnl.append((sell[0],sell[1],'sell',sell[2],row['date'][i],row['high'][i],-sl,'s/l hit',i))
#                 break
#             elif predictions[i] == 2:
#                 sell_trades_pnl.append((sell[0],sell[1],'sell',sell[2],row['date'][i],row['close'][i],
#                                     (sell [2]-row['close'][i]),'prediction change',i))
#                 break

# %%
sl = 0.0010
tp = 0.0040

for index, row in df.iterrows():
    if ~sy1.empty:
        #if it's not empty then check for sl and tp
        sy1 = check_price(sy1, row['open'], row['high'], row['low'], row['datetime'], signal)
    #if buy/sell signal received
    if signal != "":
        if signal == "Buy":
            sy1 = sys1(sy1,2,row['open'],row['datetime'],sl,tp)
        if signal == "Stay":
            # sy1 = sys1(sy1,1,row['open'],row['datetime'],sl,tp)
            signal = ""
        if signal == "Short":
            sy1 = sys1(sy1,0,row['open'],row['datetime'],sl,tp)
            signal = ""
            
    open_list = np.append(open_list,row['open'])
    close_list = np.append(close_list,row['close'])
    high_list = np.append(high_list,row['high'])
    low_list = np.append(low_list,row['low'])
    feature = []

    if index > 59:
        for i in supported:
            feature = extract_by_type(i, open_prices=open_list, close_prices=close_list, high_prices=high_list, low_prices=low_list)
        
        df = pd.DataFrame(feature)
        df = df.transpose()
        df.columns = list_is
        df.insert(0,"low",low_list)
        df.insert(0,"high",high_list)
        df.insert(0,"open",open_list)
        df.insert(0,"close",close_list)
        cols_to_norm = ["ROCP1", "ROCP2", "norm_macd", "norm_signal", "norm_hist", "macdrocp", "singalrocp", "histrocp",
            "rsi6", "rsi12", "rsi24", "rsi6rocp", "rsi12rocp", "rsi24rocp", "UO", "upperBOLL", "middleBOLL",
            "lowerBOLL", "MA5rocp", "MA10rocp", "MA20rocp", "MA25rocp", "MA30rocp", "MA40rocp", "MA50rocp", "MA60rocp", 
            "MA5", "MA10", "MA20", "MA25", "MA30", "MA40", "MA50", "MA60", "Slow_stochk", "Slow_stochd", 
            "Fast_stochk", "Fast_stochd", "Fast_stoch_rsik", "Fast_stoch_rsid", "AO","ROC5", "ROC10", "ROC20",
            "ROC25", "WILLR" ]
        df[cols_to_norm] = StandardScaler().fit_transform(df[cols_to_norm])
        
        df_X = df.iloc[:, 0:50].values
        # open_list = open_list[1:]
        # close_list = close_list[1:]
        # high_list = high_list[1:]
        # low_list = low_list[1:]
        y_pred = classifier.predict(df_X)
        # print(y_pred)
        y_pred = pd.DataFrame(y_pred)
        y_pred.columns = ['Short', 'Stay', 'Buy']
        y_pred = y_pred.astype(float)

        # define the predictions
        def enc (row):
          if (row['Short'] > row['Stay'] and 
              row['Short'] > row['Buy']  ):
              return '0'
          else:
              if (row['Stay'] > row['Short'] and 
                  row['Stay'] > row['Buy']    ):
                  return '1'
              else:
                  if (row['Buy'] > row['Short'] and 
                      row['Buy'] > row['Stay'] ):
                      return '2'
                  else:
                      return 'nan'
                  

        y_pred['Predictions'] = y_pred.apply(lambda row: enc(row), axis=1)
        predictions = y_pred['Predictions']
        predictions = predictions[60:].astype(int)

        if predictions[df.index[-1]] == 0:
            signal = "Short"
        if predictions[df.index[-1]] == 1:
            signal = "Stay"
        if predictions[df.index[-1]] == 2:
            signal = "Buy"
        print(signal,index)
        if ~sy1.empty:
            #if it's not empty then check for sl and tp at close price
            sy1 = check_price(sy1, row['close'], row['high'], row['low'], row['datetime'], signal)
# Out:
# Short 60
# Short 61
# Short 62
# Short 63
# Short 64
# Short 65
# Short 66
# Short 67
# Short 68
# Short 69
# Stay 70
# Buy 71
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# Short 72
# Buy 73
# profit/loss
# profit/loss
# profit/loss
# Short 74
# Buy 75
# profit/loss
# Stay 76
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 77
# Short 78
# Short 79
# Stay 80
# Buy 81
# S/L
# S/L
# S/L
# S/L
# S/L
# Buy 82
# Buy 83
# S/L
# Buy 84
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 85
# Buy 86
# profit/loss
# S/L
# Short 87
# Stay 88
# Buy 89
# S/L
# S/L
# S/L
# Buy 90
# Buy 91
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 92
# Stay 93
# Buy 94
# S/L
# S/L
# S/L
# Short 95
# Short 96
# Short 97
# Short 98
# Stay 99
# Stay 100
# Stay 101
# Buy 102
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# Short 103
# Short 104
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 105
# Buy 106
# S/L
# Short 107
# Short 108
# Short 109
# Short 110
# Short 111
# Short 112
# Short 113
# Buy 114
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# Short 115
# Stay 116
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 117
# Buy 118
# Stay 119
# Short 120
# Stay 121
# Short 122
# Buy 123
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# Stay 124
# Buy 125
# Buy 126
# Short 127
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 128
# Short 129
# Short 130
# Buy 131
# T/P
# T/P
# T/P
# T/P
# profit/loss
# profit/loss
# profit/loss
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 132
# Short 133
# Short 134
# Short 135
# Buy 136
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# profit/loss
# profit/loss
# profit/loss
# S/L
# Short 137
# Short 138
# Buy 139
# S/L
# S/L
# S/L
# S/L
# Stay 140
# Short 141
# Stay 142
# Stay 143
# Buy 144
# profit/loss
# Stay 145
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 146
# S/L
# Stay 147
# Stay 148
# Buy 149
# S/L
# S/L
# Short 150
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Stay 151
# Stay 152
# Short 153
# Stay 154
# Stay 155
# Stay 156
# Buy 157
# S/L
# Buy 158
# Stay 159
# Buy 160
# S/L
# S/L
# S/L
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 161
# Stay 162
# Buy 163
# Short 164
# Short 165
# Buy 166
# S/L
# S/L
# S/L
# S/L
# S/L
# Buy 167
# S/L
# Buy 168
# Buy 169
# Short 170
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Stay 171
# Stay 172
# Stay 173
# Buy 174
# T/P
# T/P
# T/P
# T/P
# Stay 175
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Stay 176
# Short 177
# Short 178
# Short 179
# Short 180
# Short 181
# Short 182
# Stay 183
# Stay 184
# Stay 185
# Short 186
# Buy 187
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# Buy 188
# profit/loss
# profit/loss
# Buy 189
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 190
# S/L
# Buy 191
# profit/loss
# Buy 192
# profit/loss
# profit/loss
# Short 193
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 194
# S/L
# S/L
# Buy 195
# S/L
# Short 196
# Buy 197
# S/L
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 198
# S/L
# Buy 199
# profit/loss
# Buy 200
# Buy 201
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# S/L
# S/L
# Buy 202
# Buy 203
# S/L
# Buy 204
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 205
# Buy 206
# Buy 207
# profit/loss
# profit/loss
# profit/loss
# profit/loss
# profit/loss
# Short 208
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 209
# Stay 210
# Short 211
# Short 212
# Stay 213
# Stay 214
# Stay 215
# Stay 216
# Stay 217
# Stay 218
# Stay 219
# Short 220
# Short 221
# Stay 222
# Stay 223
# Stay 224
# Stay 225
# Stay 226
# Stay 227
# Stay 228
# Stay 229
# Stay 230
# Stay 231
# Stay 232
# Stay 233
# Stay 234
# Stay 235
# Stay 236
# Short 237
# Short 238
# Short 239
# Short 240
# Short 241
# Short 242
# Short 243
# Short 244
# Short 245
# Short 246
# Short 247
# Short 248
# Stay 249
# Stay 250
# Stay 251
# Stay 252
# Short 253
# Stay 254
# Short 255
# Short 256
# Buy 257
# T/P
# T/P
# T/P
# T/P
# T/P
# T/P
# T/P
# profit/loss
# profit/loss
# profit/loss
# profit/loss
# profit/loss
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# S/L
# Buy 258
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 259
# S/L
# Buy 260
# S/L
# Buy 261
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 262
# profit/loss
# profit/loss
# Buy 263
# S/L
# Buy 264
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 265
# Buy 266
# Buy 267
# profit/loss
# profit/loss
# profit/loss
# Short 268
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# Short 964
# Short 965
# Buy 966
# S/L
# S/L
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 967
# Buy 968
# S/L
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 969
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 970
# profit/loss
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 971
# T/P
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 972
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 973
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 974
# profit/loss
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 975
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 976
# S/L
# Stay 977
# Buy 978
# profit/loss
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 979
# Stay 980
# Buy 981
# T/P
# T/P
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 982
# profit/loss
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Stay 983
# Stay 984
# Short 985
# Stay 986
# Short 987
# Short 988
# Short 989
# Buy 990
# S/L
# S/L
# profit/loss
# profit/loss
# profit/loss
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Buy 991
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Short 992
# Buy 993
# S/L
# S/L
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kohli\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Stay 994
# Short 995
# Stay 996
# Short 997
# Short 998
# Stay 999

# %%
sy1
# Out:
#     size  open_rate            open_date       sl       tp  close_rate  \
# 0      0    0.67870  2019-11-15 10:00:00  0.67770  0.68270     0.68117
# 1      0    0.68049  2019-11-15 14:00:00  0.67949  0.68449     0.67913
# 2      0    0.68136  2019-11-15 18:00:00  0.68036  0.68536     0.67913
# 3      0    0.68171  2019-11-17 18:00:00  0.68071  0.68571     0.67913
# 4      0    0.68121  2019-11-17 22:00:00  0.68021  0.68521     0.67913
# ..   ...        ...                  ...      ...      ...         ...
# 703    0    0.69037  2020-06-17 17:00:00  0.68937  0.69437     0.68838
# 704    2    0.68838  2020-06-17 21:00:00  0.68738  0.69238         NaN
# 705    0    0.68772  2020-06-18 05:00:00  0.68672  0.69172         NaN
# 706    0    0.68577  2020-06-18 13:00:00  0.68477  0.68977         NaN
# 707    0    0.68418  2020-06-18 17:00:00  0.68318  0.68818         NaN
#
#               close_date      P/L
# 0    2019-11-19 06:00:00  0.00247
# 1    2019-11-18 22:00:00 -0.00136
# 2    2019-11-18 22:00:00 -0.00223
# 3    2019-11-18 22:00:00 -0.00258
# 4    2019-11-18 22:00:00 -0.00208
# ..                   ...      ...
# 703  2020-06-17 17:00:00 -0.00199
# 704                  NaN      NaN
# 705                  NaN      NaN
# 706                  NaN      NaN
# 707                  NaN      NaN
#
# [708 rows x 8 columns]

# %%
for i in range(len(sy1)):
    if sy1['size'][i] == 1:
        sy1.drop([i], inplace=True)

# %%
sy1.reset_index()
# Out:
#      index size  open_rate            open_date       sl       tp  close_rate  \
# 0        0    2    0.67901  2019-11-15 06:00:00  0.67701  0.68201     0.68417
# 1        1    0    0.67870  2019-11-15 10:00:00  0.67670  0.68170     0.68417
# 2        2    0    0.68049  2019-11-15 14:00:00  0.67849  0.68349     0.67728
# 3        3    0    0.68136  2019-11-15 18:00:00  0.67936  0.68436     0.67824
# 4        4    0    0.68171  2019-11-17 18:00:00  0.67971  0.68471     0.67917
# ..     ...  ...        ...                  ...      ...      ...         ...
# 705    705    2    0.68926  2020-06-17 13:00:00  0.68726  0.69226     0.68638
# 706    706    0    0.69037  2020-06-17 17:00:00  0.68837  0.69337     0.68638
# 707    707    2    0.68838  2020-06-17 21:00:00  0.68638  0.69138         NaN
# 708    708    0    0.68772  2020-06-18 05:00:00  0.68572  0.69072         NaN
# 709    709    0    0.68577  2020-06-18 13:00:00  0.68377  0.68877         NaN
#
#               close_date    P/L
# 0    2019-11-19 10:00:00  0.003
# 1    2019-11-19 10:00:00  0.003
# 2    2019-11-22 02:00:00 -0.002
# 3    2019-11-20 18:00:00 -0.002
# 4    2019-11-19 06:00:00 -0.002
# ..                   ...    ...
# 705  2020-06-17 21:00:00 -0.002
# 706  2020-06-17 17:00:00 -0.002
# 707                  NaN    NaN
# 708                  NaN    NaN
# 709                  NaN    NaN
#
# [710 rows x 9 columns]

# %%
total = 0
count = 0
profit = 0
positive = 0
negative = 0
for index, row in sy1.iterrows():
    total += 1
    if np.isnan(row['P/L']):
        count += 1
    else:
        #it's divided by 10000 when calculating the sl/tp level, so when calculating the profit, we need to *10000
        profit += row['P/L'] * 10000
        if row['P/L'] > 0:
            positive += 1
        else:
            negative += 1
print("Total amount of trade made: ", total, ", and", count, "trades not closed")        
print("There are", positive, "winning trades and", negative, "lossing trades.", "Based on current closed trades, the P/L is : ", profit)
# Out:
# Total amount of trade made:  708 , and 4 trades not closed
# There are 316 winning trades and 388 lossing trades. Based on current closed trades, the P/L is :  97.7999999999759

# %%
df_X[90]
# Out:
# array([ 0.67848   ,  0.67928   ,  0.67934   ,  0.67846   , -0.31290481,
#        -0.03839472, -0.22581254, -0.18267367, -0.19848171, -0.17030442,
#        -0.1581386 , -0.13153591, -0.77684496, -0.70789841, -0.75851253,
#        -0.83389448, -0.76476655, -0.70924667, -1.03908571, -0.30953605,
#         0.23067031,  0.67908404, -0.3297741 , -0.32807309, -0.17638129,
#        -0.22161568, -0.01006738, -0.24494833, -0.25666686, -0.3605681 ,
#         0.23067031,  0.21486582,  0.27708391,  0.25134847,  0.23281704,
#         0.16480121,  0.20200228,  0.23874164, -1.336041  , -1.2171032 ,
#        -1.46802656, -1.33499654, -1.10549457, -0.98973537, -0.1351228 ,
#        -0.33326524, -0.3335082 , -0.18614568, -0.23330593, -1.44101828])

# %%
total = 0
count = 0
profit = 0
positive = 0
negative = 0
for index, row in sy1.iterrows():
    total += 1
    if np.isnan(row['P/L']):
        count += 1
    else:
        profit += row['P/L']
        if row['P/L'] > 0:
            positive += 1
        else:
            negative += 1
print("Total amount of trade made: ", total, ", and", count, "trades not closed")        
print("There are", positive, "winning trades and", negative, "lossing trades.", "Based on current closed trades, the P/L is : ", profit)
# Out:
# Total amount of trade made:  558 , and 0 trades not closed
# There are 532 winning trades and 26 lossing trades. Based on current closed trades, the P/L is :  0.6919400000000026

# %%
for i in range(len(sy1['P/L'])):
    if sy1['P/L'][i] < 0:
        print(sy1['P/L'][i])
# Out:
# -0.00028999999999990145
# -0.0004199999999998649
# -0.00019999999999997797
# -0.0014899999999998803
# -0.0012399999999999078
# -0.0004899999999999904
# -0.00047999999999992493
# -0.0007500000000000284
# -0.0006300000000000194
# -0.0023400000000000087
# -0.0010999999999999899
# -0.0027200000000000557
# -0.0007200000000000539
# -0.0003700000000000925
# -0.002549999999999941
# -0.003269999999999884
# -9.999999999843467e-06
# -0.00039999999999995595
# -0.0023900000000000032
